# %% [markdown]
# # If Else Statements In Python

# %%
x = 10
y = 100

if x > y:
print("X is greater than Y") #give indentation error
# Out:
#   Cell In[1], line 5
#     print("X is greater than Y") #give indentation error
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
x = 10
y = 100

if x > y:
    print("X is greater than Y")
else:
    print("Y is greater than X")
# Out:
# Y is greater than X

# %%
x = 10
y = 100

if x > y:
    print("X is greater than Y")
if y > x:
    print("Y is greater than X")
    print("condition 2")
else:
    print("Invalid")
# Out:
# Y is greater than X
# condition 2

# %%
x = 10
y = 100

if x > y:
    print("X is greater than Y")
elif y > x:
    print("Y is greater than X")
    print("condition 2")
    if x != y:
        print("True")
else:
    print("Invalid")
# Out:
# Y is greater than X
# condition 2
# True

# %%
num = float(input("Enter any number : "))

if num % 2 == 0:
    if num % 5 == 0:
        print(num,"divisible by 2 and 5")
    else:
        print("No")
else:
    print("Not")
# Out:
# Enter any number :  20
# 20.0 divisible by 2 and 5

# %%
num = float(input("Enter any number : "))

if num % 2 == 0:
    if num % 5 == 0:
        print(num,"divisible by 2 and 5")
    else:
        print("No")
else:
    print("Not")
# Out:
# Enter any number :  8
# No

# %%
from IPython.display import Image
Image("pic.png")

# %%
amount = 0
net_units = float(input("Enter the unit value : "))

if net_units <= 100:
    amount = 0

elif net_units > 100 and net_units <= 200:
    amount = (net_units - 100) * 5

elif net_units > 200:
    amount = ((net_units - 200) *10)+500
else:
    print("Invalid Unit")

print("Amount paid to :",amount)
# Out:
# Enter the unit value :  201
# Amount paid to : 510.0

# %%
amount = 0
net_units = float(input("Enter the unit value : "))

if net_units <= 100:
    amount = 0

elif net_units > 100 and net_units <= 200:
    amount = (net_units - 100) * 5

elif net_units > 200:
    amount = ((net_units - 200) *10)+500
else:
    print("Invalid Unit")

print("Amount paid to :",amount)
# Out:
# Enter the unit value :  350
# Amount paid to : 2000.0

# %%
from IPython.display import Image, display

# Display the image
display(Image("if-else.png"))

# %% [markdown]
# # Assingment 1

# %%
length = int(input("Enter the value of length : "))
breadth = int(input("Enter the value of breadth : "))
# Out:
# Enter the value of length :  6
# Enter the value of breadth :  6

# %%
if length == breadth:
    print("It is sqaure")
else:
    print("Not")
# Out:
# It is sqaure

# %%
length = int(input("Enter the value of length : "))
breadth = int(input("Enter the value of breadth : "))
# Out:
# Enter the value of length :  6
# Enter the value of breadth :  7

# %%
if length == breadth:
    print("It is sqaure")
else:
    print("Not")
# Out:
# Not

# %% [markdown]
# # Assignment 2

# %%
num1 = int(input("Enter the first value : "))
num2 = int(input("Enter the second value : "))
num3 = int(input("Enter the third value : "))
# Out:
# Enter the first value :  58
# Enter the second value :  87
# Enter the third value :  46

# %%
if (num1 > num2) and (num1 > num3):
    greater = num1
elif (num2 > num3) and (num2 > num1):
    greater = num2
else:
    greater = num3

print(greater,"is the greatest number.")
# Out:
# 87 is the greatest number.

# %% [markdown]
# # Assignment 3

# %%
held_class = int(input("Enter total held classes : "))
attend_class = int(input("Enter total attend classes : "))
# Out:
# Enter total held classes :  20
# Enter total attend classes :  15

# %%
attend_ratio = (held_class / attend_class) * 100

# %%
attend_ratio
# Out:
# 133.33333333333331

# %%
if attend_ratio >= 75:
    print("Allowed")
else:
    print("Not Allowed")
# Out:
# Allowed

# %% [markdown]
# # Assignment 4

# %%
marks = float(input("enter the marks: "))
# Out:
# enter the marks:  89

# %%
if marks >= 90:
    grade = "A+"
elif marks > 80 and marks < 90:
    grade = "A"
elif marks > 60 and marks < 80:
    grade = "B"
elif marks > 50 and marks < 60:
    grade = "C"
elif marks > 45 and marks < 50:
    grade = "D"
elif marks > 25 and marks < 45:
    grade = "E"
else:
    grade = "F"

print("Your grade is :",grade)
# Out:
# Your grade is : A
